# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options = options)

driver.get("https://www.instagram.com/accounts/login/")
print("수동으로 인증 시작!")
time.sleep(30)

# "instagram_cookies.pkl" -> 인스타그램이 우리에게 내려주는 쿠키
# wb -> 2진수로 되어있는 이름을 쓰겠다는 뜻(write binary)
with open ("instagram_cookies.pkl", "wb") as f :
    pickle.dump(driver.get_cookies(), f)  # 인스타그램에서 주는 모든 쿠키값을 직렬화해서 찾아옴

print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동으로 인증 시작!
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options = options)

driver.get("https://www.instagram.com/")

with open ("instagram_cookies.pkl", "rb") as f :  # rb => read binary
    cookies = pickle.load(f)
for cookie in cookies :
    driver.add_cookie(cookie)  

driver.refresh() # 새로고침
time.sleep(5)


try : 
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)
except : 
    pass

keyword = "나이키"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(5)

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0,document.body.scrollheight);")
    time.sleep(3)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try :
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url" : url, "caption" : caption})
    except  Exception as e :
        print (f"캡션 추출 실패 : {url} | 에러 : {e} ")
        continue

driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/CsfaG1XJ9bz/
# Photo by 임 정현 on May 20, 2023. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/C2McgF-uQLd/
# Photo by 일본구매대행 l 분더스토리 l WUNDER STORY on January 17, 2024. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DGVKSMyvl-v/
# Photo shared by 밍서 MING on February 21, 2025 tagging @nike, and @nikeseoul. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DGSaTzZJ7yI/
# Photo shared by 짱구미 ~(˘▾˘)~ on February 20, 2025 tagging @nikeswim. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DGu5921PaPM/
# Photo by 광주붙임머리 그린룸💚 | 붙임머리 레이어드컷  | 붙임머리전문점 in 광주광역시. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/C8E7i0avHBi/
# Photo by 동해 in Busan 釜山, South Korea with @nike, @gentlemonster, @orleansstore_official, and @thomasmore_official. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DKbHbQ6PmkM/
# Photo shared by 슬로후 | SLOHOO on June 02, 2025 tagging @supremenewyork, @newerakorea, @nikeseoul, @21ice_jewelry, and @lydhwa. 스포츠웨어, 포스터 및 문구: 'S NIKE Supreme Screw Ball ScrewBallLogo Logo NSW Tech Fleece Full Zip ACGDri-Fit ACG Dri-Fit Lightweight Gloves Tech Woven Open Hem Pants Air Force 1 AirForce1407Low '07 Low'의 낙서 그림일 수 있음.
# ============================================================
# https://www.instagram.com/p/DJeXZbaykuh/
# Photo by Summer Yun in Seoul, Korea with @nikerunning, @nikewomen, @nikeseoul, and @n1rc_180607. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/C6_Ls5APjrq/
# Photo by 유 신호 in 용인 수지구 풍덕천동 with @nike, and @badass_artlab. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/C1T9AweSysf/
# 나이키 나이키스윔 스윔메트로 나이키수영복  수영복 수영 수영장 수영복추천 수영복코디 수영일기 수영맛집 수영스타그램 swim swimming swimwear siwmsuit swimsuits
# ============================================================
