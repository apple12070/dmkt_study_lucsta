# %% [markdown]
# ### 🖱 미션 No.1 ) 알라딘 사이트에서 '자기계발' 베스트 도서의 제목과 저자를 수집하세요. (*셀레니움을 활용해서)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--disable-dev-shm-usage') 
chrome_options.add_argument('--window-size=1920x1080')
chrome_options.add_argument('--start-maximized')
chrome_options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36')
chrome_options.add_argument('--lang=ko_KR')


service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=336'
driver.get(url)
time.sleep(5)

books = driver.find_elements(By.CSS_SELECTOR, 'div.ss_book_box')

for idx, book in enumerate(books):
    try:
        title = book.find_element(By.CSS_SELECTOR, 'a.bo3').text.strip()
        author_tags = book.find_elements(By.CSS_SELECTOR, "a[href*='AuthorSearch']")
        idx += 1
        if author_tags:
            author = author_tags[0].text.strip()
        else:
            author = "저자 정보 없음"

        print(f"{idx}. 제목 : {title} — 저자 : {author}")

    except Exception as e:
        print(f"{idx}. 에러 : {e}")
        continue

driver.quit()
# Out:
# 1. 제목 : 고전이 답했다 마땅히 가져야 할 부에 대하여 — 저자 : 고명환
# 2. 제목 : 열심히 살아도 불안한 사람들 — 저자 : 랄리타 수글라니
# 3. 제목 : 미묘한 메모의 묘미 — 저자 : 김중혁
# 4. 제목 : 듀얼 브레인 — 저자 : 이선 몰릭
# 5. 제목 : 소크라테스는 왜 질문만 했을까 — 저자 : 시노하라 마코토
# 6. 제목 : 행동은 불안을 이긴다 — 저자 : 롭 다이얼
# 7. 제목 : 매일 더 성장하고 싶은 당신을 위한 모닝 필사 — 저자 : 이재은
# 8. 제목 : 조종당하는 인간 — 저자 : 김석재
# 9. 제목 : 어른의 품격을 채우는 100일 필사 노트 — 저자 : 김종원
# 10. 제목 : 살아갈 날들을 위한 괴테의 시 — 저자 : 김종원
# 11. 제목 : 퓨처 셀프 30만 부 기념 스페셜 에디션 — 저자 : 벤저민 하디
# 12. 제목 : 고전이 답했다 마땅히 살아야 할 삶에 대하여 — 저자 : 고명환
# 13. 제목 : 아티스트 웨이 : 30주년 기념 특별판 — 저자 : 줄리아 캐머런
# 14. 제목 : 데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본) — 저자 : 데일 카네기
# 15. 제목 : 생각의 주도권을 디자인하라 — 저자 : 박용후
# 16. 제목 : 세이노의 가르침 (블랙 에디션) — 저자 : 세이노(SayNo)
# 17. 제목 : 이어령의 말 — 저자 : 이어령
# 18. 제목 : 왓츠 유어 드림 — 저자 : 사이먼 스큅
# 19. 제목 : 내 이력서를 보는 사람은 누구일까? — 저자 : 김진영
# 20. 제목 : 그릿 Grit — 저자 : 김주환
# 21. 제목 : 인생을 바꾸는 이메일 쓰기 — 저자 : 이슬아
# 22. 제목 : 너라는 브랜드를 마케팅하라 — 저자 : 이소라
# 23. 제목 : AI 에이전트 트렌드 & 활용백과 — 저자 : 김덕진
# 24. 제목 : 오늘을 남기는 기록, 스마트폰 사진 촬영 & 보정 — 저자 : 민썸
# ...
