# %%
# pandas 라이브러리 : 전처리 & 기본 그래프의 시각화에 최적화 되어있음
# 파이썬에서 문서 (*파일) 처리하는 기본.기초 지식 학습
# 특정 파일 오픈 -> 파일 읽기 || 파일 쓰기 -> 파일 닫기

# 파일 처리를 위한 내장함수 -> open(실행하고자 하는 파일경로, 파일처리 모드에 대한 옵션값, 인코딩 옵션)
# 파일 처리 모드 옵션 -> r(ead) / w(rite) : 쓰기 -> 기존파일에 어떤 값을 쓰기위한 목적 / a(dd) -> 새로운 데이터 추가
# 의 세 가지 모드가 있음
# 인코딩 옵션 -> 웹을 통해서 주고 받는 문서 파일 -> 영어 -> 한글 + 특수문자 + 이모지
# 우리의 언어로 작성한 문자열 -> 인코딩 -> 컴퓨터 -> 디코딩 -> 우리의 언어로 다시 확인
# utf-8-sig (전세계에서 컴퓨터를 활용하여 어떤 문서를 만들겠다는 기관들이 제출한 규약 - utf-8을 이용하여 인코딩,디코딩을 하면 모든 문서들이 변환이 됨)

# 파일 포맷 : 데이터 분야 가장 빈번하게 많이 사용하는 포맷
# CSV = 엑셀 = 행 & 열, json = 프론트 & 백엔드, xml = 크롤링, api
# csv = comma-seperated values = 실제 데이터 취급 시, 정말 많이 볼 수 있는 데이터 포맷 양식
# xml = Extensible Markup Language = 유연한 마크업 언어로 되어있는 데이터 포맷 양식
# json = Javascript Object Notation = 클라이언트와 서버가 데이터를 서로 주고받을 때 사용하는 데이터 포맷 양식
