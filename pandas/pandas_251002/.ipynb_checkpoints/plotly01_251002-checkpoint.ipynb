# %%
보다 세부적으로 EDA를 활용해서 데이터를 확인 및 검증하기 위한 방법론
feature = column 상관관계 분석
데이터 사이언티스트/분석가가 되겠다고 생각하는 사람은 결국 데이터 내 feature간 상관관계를 누가 더 세부적이고 심도있게 밝혀내는가의 역량이 가장 중요!! 
수집한 데이터의 상관관계를 얼마나 잘 검출해내는가 -> 심증이 아니라 물증으로 만들어내는 사람이 경쟁력 있는 데이터 사이언티스트/데이터 분석가가 됨

heatmap 그래프
scatter 그래프
-> 이 두가지를 통해서 데이터의 상관관계를 확인할 수 있음.
-> 피어슨 상관관계를 통해 확인할거임. 너무 부담갖지 마!...가 되겠냐고요 

** 상관관계를 체크 및 확인하기 위해서 상관계수라는 것을 사용함
상관계수 : 1에 수렴할수록 상관관계가 높다 / 0에 수렴할수록 상관관계가 없다. 라고 판단함

# %%
피어슨 : 영국의 수학자 & 통계학자
현대 통계학의 아버지
> 어떤 사물 혹은 사건 간의 연관성이 존재한다고 생각
> 이것을 물증 & 수치로 변환할 수는 없을까?


** 피어슨 상관계수 = 공분산 / (A 데이터의 표준편차 X B 데이터의 표준편차)

공분산 : A 데이터와 B 데이터가 함께 변하는 정도(수치)
        함께 (공) // 변하는 것 (분산)
        > A 데이터의 표준편차 * B데이터의 표준편차의 합

표준편차 : 어떤 데이터들의 집합이 존재하고, 그 데이터들의 집합의 평균값이 존재하는데 그 평균값으로부터 평균적으로 얼만큼 떨어져있는가를 확인하고자 할 때 표준편차를 계산함
           -> 표준편차를 계산하기 위해서는 분산이 필요. -> 분산의 제곱근이 표준편차


#직접 계산할 일은 없으니 안심하라는데 일단 난 이해 못함
